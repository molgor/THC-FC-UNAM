# %% [markdown]
# # Módulo 2
# ## Tipos de datos en Python
# - Enteros
# - Flotantes
# - Booleanos
# - String (cadena de caracteres)

# %%
entero = 43
flotante = 23.54665
booleano = False

# %% [markdown]
# # Operaciones

# %%
type(booleano + booleano)
# Out:
# int

# %%
cadena1 = "Hola esta es una caden"
cadena2 = "Esta es otra cadena"

# %%
cadena1 + " <---> " +cadena2
# Out:
# 'Hola esta es una cadena <---> Esta es otra cadena'

# %% [markdown]
# ## Cadenas F (F - Strings)

# %%
nombre = "Gaél"
saludo = f"Hola {nombre}, buenos dias!"

# %% [markdown]
#  ## Datos múltiples
# - Listas
# - Tuplas
# - Sets (Conjuntos)
# - Dictionarios

# %%
lista = [56, 343.4343, saludo]

# %%
lista[0] = 1.0

# %%
lista
# Out:
# [1.0, 3424.3435, 'Hola Gaél, buenos dias!']

# %%
nombres = ["Gaél", "Antonio", "Laura", "Jimena","José"]

# %% [markdown]
# ### Ordenar (Sort)

# %%
nombres.sort(reverse=True)

# %%
nombres
# Out:
# ['Laura', 'José', 'Jimena', 'Gaél', 'Antonio']

# %% [markdown]
# ### Tuplas, son arreglos inmutables. Los valores no se pueden sobreescribir

# %%
tupla = (1, 2, 3, 4, 5)

# %%
tupla[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 tupla[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Conjuntos (Set)
# Operaciones con conjuntos. Definimos conjuntos $A$ y $B$

# %%
A = {1, 2, 3, 4, 5}
B = { 3, 4, 5, 6,7,8,9}

# %% [markdown]
# Podemos hacer operaciones, por ejemplo: $ A \bigcup B$

# %%
A | B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# $ A \bigcap B $

# %%
A & B
# Out:
# {3, 4, 5}

# %% [markdown]
# ## Convertir entre tipos (Casting)

# %%
lista = [1,2,3,3,3,3,4,5,6,7]

# %% [markdown]
# ## Convertir a conjunto, elimina repeticiones

# %%
slista = list(set(lista))

# %% [markdown]
# ## Dictionarios
# También conocidos como *Mapeos Hash* (Hash Tables)
#
# {
# LLAVE1 : Valor
# LLAVE2 : Valor2
# LLAVE3 : Valor3
# }

# %%
perfil = { "nombre" : "Jose", "edad" : 30, "ocupacion": "carpintero", "altura": 1.70}

# %% [markdown]
# ## Ciclos For

# %%
nombres
# Out:
# ['Laura', 'José', 'Jimena', 'Gaél', 'Antonio']

# %%
for nombre in nombres:
    saludo = f"Hola {nombre}, buenos dias!"
    print(saludo)
# Out:
# Hola Laura, buenos dias!
# Hola José, buenos dias!
# Hola Jimena, buenos dias!
# Hola Gaél, buenos dias!
# Hola Antonio, buenos dias!

# %% [markdown]
# ## Comprensión de listas (List comprehension)

# %%
[ f"Hola {nombre}, buenos días!" for nombre in nombres]
# Out:
# ['Hola Laura, buenos días!',
#  'Hola José, buenos días!',
#  'Hola Jimena, buenos días!',
#  'Hola Gaél, buenos días!',
#  'Hola Antonio, buenos días!']

# %%
### Elevar al cuadrado cada valor

# %%
X = [ x for x in range(1,200)]

# %%
Y

# %% [markdown]
# ## Ejercicio
# Implementar el cálculo de una parábola
#
# Fórmula general de la parábola: $Y = Bx^2 + C$
#
# Generar las x
#
# x = range(1, 100)
# Definir
# B= 2.2
# C= 1.2
#
# Calcular Y con ciclos For y Lists Comprehension
# Y

# %% [markdown]
# Bonus: Grafica X y Y con matplotlib
